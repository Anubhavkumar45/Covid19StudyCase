# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import geopandas as gpd
from shapely.geometry import Point,Polygon
import descartes

# %%
df= pd.read_csv("./data/coronovirus_updated_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Province/State Country/Region      Lat      Long     Date  \
# 0           0            NaN       Thailand  15.0000  101.0000  1/22/20
# 1           1            NaN          Japan  36.0000  138.0000  1/22/20
# 2           2            NaN      Singapore   1.2833  103.8333  1/22/20
# 3           3            NaN          Nepal  28.1667   84.2500  1/22/20
# 4           4            NaN       Malaysia   2.5000  112.5000  1/22/20
#
#    Confirmed  Recovered  Deaths
# 0          2          0       0
# 1          2          0       0
# 2          0          0       0
# 3          0          0       0
# 4          0          0       0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Province/State', 'Country/Region', 'Lat', 'Long', 'Date',
#        'Confirmed', 'Recovered', 'Deaths'],
#       dtype='object')

# %%
df = df.rename(columns={'Unnamed: 0':'Index','Province/State':'Province_State', 'Country/Region':'Country_Region'})

# %%
df.shape
# Out:
# (26334, 9)

# %%
df.dtypes
# Out:
# Index               int64
# Province_State     object
# Country_Region     object
# Lat               float64
# Long              float64
# Date               object
# Confirmed           int64
# Recovered           int64
# Deaths              int64
# dtype: object

# %%
df.head(10)
# Out:
#    Index    Province_State Country_Region      Lat      Long     Date  \
# 0      0               NaN       Thailand  15.0000  101.0000  1/22/20
# 1      1               NaN          Japan  36.0000  138.0000  1/22/20
# 2      2               NaN      Singapore   1.2833  103.8333  1/22/20
# 3      3               NaN          Nepal  28.1667   84.2500  1/22/20
# 4      4               NaN       Malaysia   2.5000  112.5000  1/22/20
# 5      5  British Columbia         Canada  49.2827 -123.1207  1/22/20
# 6      6   New South Wales      Australia -33.8688  151.2093  1/22/20
# 7      7          Victoria      Australia -37.8136  144.9631  1/22/20
# 8      8        Queensland      Australia -28.0167  153.4000  1/22/20
# 9      9               NaN       Cambodia  11.5500  104.9167  1/22/20
#
#    Confirmed  Recovered  Deaths
# 0          2          0       0
# 1          2          0       0
# 2          0          0       0
# 3          0          0       0
# 4          0          0       0
# 5          0          0       0
# 6          0          0       0
# 7          0          0       0
# 8          0          0       0
# 9          0          0       0

# %%
df = df[['Province_State', 'Country_Region', 'Lat', 'Long', 'Date',
       'Confirmed', 'Recovered', 'Deaths']]

# %%
df.isna().sum()
# Out:
# Province_State    8151
# Country_Region       0
# Lat                  0
# Long                 0
# Date                 0
# Confirmed            0
# Recovered            0
# Deaths               0
# dtype: int64

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed     Recovered        Deaths
# count  26334.000000  26334.000000  26334.000000  26334.000000  26334.000000
# mean      31.742141    -36.138645    153.451204     57.770791      5.068049
# std       18.795646     80.132333   2487.497340   1295.084856    103.669715
# min      -41.454500   -157.858400      0.000000      0.000000      0.000000
# 25%       27.610400    -93.061600      0.000000      0.000000      0.000000
# 50%       37.831650    -74.304550      0.000000      0.000000      0.000000
# 75%       42.315400     21.005900      0.000000      0.000000      0.000000
# max       71.706900    174.886000  67800.000000  56927.000000   3122.000000

# %%
#number of cases per date
df.groupby('Date')['Confirmed', 'Recovered', 'Deaths'].sum()
# Out:
# C:\Users\Anubhav\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2/29/20      66337      28993    2727
# 2/3/20       13522        386     414
# 2/4/20       16678        522     479
# 2/5/20       19665        633     549
# 2/6/20       22112        817     618
# 2/7/20       24953       1115     699
# 2/8/20       27100       1439     780
# 2/9/20       29631       1795     871
# 3/1/20       66907      31536    2761
# 3/10/20      67760      47743    3024
# 3/11/20      67773      49134    3046
# 3/12/20      67781      50318    3056
# 3/13/20      67786      51553    3062
# 3/14/20      67790      52960    3075
# 3/15/20      67794      54288    3085
# 3/16/20      67798      55142    3099
# 3/17/20      67799      56003    3111
# 3/18/20      67800      56927    3122
# 3/2/20       67103      33934    2803
# 3/3/20       67217      36208    2835
# 3/4/20       67332      38557    2871
# 3/5/20       67466      40592    2902
# 3/6/20       67592      42033    2931
# 3/7/20       67666      43500    2959
# 3/8/20       67707      45235    2986
# 3/9/20       67743      46488    3008

# %%
df_per_day= df.groupby('Date')['Confirmed', 'Recovered', 'Deaths'].max()
# Out:
# C:\Users\Anubhav\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df_per_day.describe()
# Out:
#           Confirmed     Recovered       Deaths
# count     57.000000     57.000000    57.000000
# mean   44840.087719  19036.368421  1740.315789
# std    26549.113590  20335.832220  1166.253145
# min      444.000000     28.000000    17.000000
# 25%    19665.000000    633.000000   549.000000
# 50%    62031.000000  10337.000000  2029.000000
# 75%    67332.000000  38557.000000  2871.000000
# max    67800.000000  56927.000000  3122.000000

# %%
#Max num of cases
df_per_day['Confirmed'].max()
# Out:
# 67800

# %%
#Min num of cases
df_per_day['Confirmed'].min()
# Out:
# 444

# %%
#date for maximum number cases
df_per_day['Confirmed'].idxmax()
# Out:
# '3/18/20'

# %%
#date for minimum number cases
df_per_day['Confirmed'].idxmin()
# Out:
# '1/22/20'

# %%
#Number of cases per country/province
df.groupby(['Country_Region'])['Confirmed', 'Recovered', 'Deaths'].max()
# Out:
# C:\Users\Anubhav\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                      Confirmed  Recovered  Deaths
# Country_Region
# Afghanistan                 22          1       0
# Albania                     59          0       2
# Algeria                     74         12       7
# Andorra                     39          1       0
# Antigua and Barbuda          1          0       0
# ...                        ...        ...     ...
# Uruguay                     50          0       0
# Uzbekistan                  15          0       0
# Venezuela                   36          0       0
# Vietnam                     75         16       0
# Zambia                       2          0       0
#
# [152 rows x 3 columns]

# %%
#Number of cases per country/province
df.groupby(['Province_State','Country_Region'])['Confirmed', 'Recovered', 'Deaths'].max()
# Out:
# C:\Users\Anubhav\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                    Confirmed  Recovered  Deaths
# Province_State     Country_Region
# Adams, IN          US                      0          0       0
# Alabama            US                     46          0       0
# Alachua, FL        US                      0          0       0
# Alameda County, CA US                      2          0       0
# Alaska             US                      6          0       0
# ...                                      ...        ...     ...
# Wyoming            US                     15          0       0
# Xinjiang           China                  76         73       3
# Yolo County, CA    US                      1          0       0
# Yunnan             China                 176        172       2
# Zhejiang           China                1232       1216       1
#
# [319 rows x 3 columns]

# %%
df['Country_Region'].value_counts()
# Out:
# US                 14079
# China               1881
# Canada               627
# Australia            513
# France               456
#                    ...
# Hungary               57
# North Macedonia       57
# Chile                 57
# Russia                57
# Barbados              57
# Name: Country_Region, Length: 152, dtype: int64

# %%
df['Country_Region'].value_counts().plot(kind='bar',figsize=(20,10))

# %%
plt.figure(figsize=(20,10))
df['Country_Region'].value_counts().plot.pie(autopct="%1.1f%%")

# %%
#How many countries affected
df['Country_Region'].unique()
# Out:
# array(['Thailand', 'Japan', 'Singapore', 'Nepal', 'Malaysia', 'Canada',
#        'Australia', 'Cambodia', 'Sri Lanka', 'Germany', 'Finland',
#        'United Arab Emirates', 'Philippines', 'India', 'Italy', 'Sweden',
#        'Spain', 'Belgium', 'Egypt', 'Lebanon', 'Iraq', 'Oman',
#        'Afghanistan', 'Bahrain', 'Kuwait', 'Algeria', 'Croatia',
#        'Switzerland', 'Austria', 'Israel', 'Pakistan', 'Brazil',
#        'Georgia', 'Greece', 'North Macedonia', 'Norway', 'Romania',
#        'Estonia', 'San Marino', 'Belarus', 'Iceland', 'Lithuania',
#        'Mexico', 'New Zealand', 'Nigeria', 'Ireland', 'Luxembourg',
#        'Monaco', 'Qatar', 'Ecuador', 'Azerbaijan', 'Armenia',
#        'Dominican Republic', 'Indonesia', 'Portugal', 'Andorra', 'Latvia',
#        'Morocco', 'Saudi Arabia', 'Senegal', 'Argentina', 'Chile',
#        'Jordan', 'Ukraine', 'Hungary', 'Liechtenstein', 'Poland',
#        'Tunisia', 'Bosnia and Herzegovina', 'Slovenia', 'South Africa',
#        'Bhutan', 'Cameroon', 'Colombia', 'Costa Rica', 'Peru', 'Serbia',
#        'Slovakia', 'Togo', 'Malta', 'Martinique', 'Bulgaria', 'Maldives',
#        'Bangladesh', 'Paraguay', 'Albania', 'Cyprus', 'Brunei', 'US',
#        'Burkina Faso', 'Holy See', 'Mongolia', 'Panama', 'China', 'Iran',
#        'Korea, South', 'France', 'Cruise Ship', 'Denmark', 'Czechia',
#        'Taiwan*', 'Vietnam', 'Russia', 'Moldova', 'Bolivia', 'Honduras',
#        'United Kingdom', 'Congo (Kinshasa)', "Cote d'Ivoire", 'Jamaica',
#        'Turkey', 'Cuba', 'Guyana', 'Kazakhstan', 'Ethiopia', 'Sudan',
#        'Guinea', 'Kenya', 'Antigua and Barbuda', 'Uruguay', 'Ghana',
#        'Namibia', 'Seychelles', 'Trinidad and Tobago', 'Venezuela',
#        'Eswatini', 'Gabon', 'Guatemala', 'Mauritania', 'Rwanda',
#        'Saint Lucia', 'Saint Vincent and the Grenadines', 'Suriname',
#        'Kosovo', 'Central African Republic', 'Congo (Brazzaville)',
#        'Equatorial Guinea', 'Uzbekistan', 'Netherlands', 'Benin',
#        'Greenland', 'Liberia', 'Somalia', 'Tanzania', 'The Bahamas',
#        'Barbados', 'Montenegro', 'Kyrgyzstan', 'Mauritius', 'Zambia',
#        'Djibouti', 'Gambia, The'], dtype=object)

# %%
len(df['Country_Region'].unique())
# Out:
# 152

# %% [markdown]
# ## Check for Distribution on map

# %%
dir(gpd)
# Out:
# ['GeoDataFrame',
#  'GeoSeries',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_compat',
#  '_config',
#  '_version',
#  'array',
#  'base',
#  'datasets',
#  'geodataframe',
#  'geopandas',
#  'geoseries',
#  'gpd',
#  'io',
#  'np',
#  'options',
#  'overlay',
#  'pd',
#  'plotting',
#  'points_from_xy',
#  'read_file',
#  'read_postgis',
#  'show_versions',
#  'sjoin',
#  'tools']

# %%
#Coverting to geodataframe
gdf01= gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df['Long'],df['Lat']))

# %%
gdf01.head()
# Out:
#   Province_State Country_Region      Lat      Long     Date  Confirmed  \
# 0            NaN       Thailand  15.0000  101.0000  1/22/20          2
# 1            NaN          Japan  36.0000  138.0000  1/22/20          2
# 2            NaN      Singapore   1.2833  103.8333  1/22/20          0
# 3            NaN          Nepal  28.1667   84.2500  1/22/20          0
# 4            NaN       Malaysia   2.5000  112.5000  1/22/20          0
#
#    Recovered  Deaths                    geometry
# 0          0       0  POINT (101.00000 15.00000)
# 1          0       0  POINT (138.00000 36.00000)
# 2          0       0   POINT (103.83330 1.28330)
# 3          0       0   POINT (84.25000 28.16670)
# 4          0       0   POINT (112.50000 2.50000)

# %%
type(gdf01)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#map plot
gdf01.plot(figsize=(20,10))

# %%
#overlapping with world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(figsize=(20,10))
ax.axis('off')
# Out:
# (-198.0, 198.00000000000006, -98.6822565, 92.32738650000002)

# %%
fig,ax = plt.subplots(figsize=(20,10))
gdf01.plot(cmap='Purples',ax=ax)
world.geometry.boundary.plot(color=None,edgecolor='k',linewidth=2,ax=ax)

# %%
#Per Country
world['continent'].unique()
# Out:
# array(['Oceania', 'Africa', 'North America', 'Asia', 'South America',
#        'Europe', 'Seven seas (open ocean)', 'Antarctica'], dtype=object)

# %%
asia = world[world['continent'] == 'Asia']
africa = world[world['continent'] == 'Africa']
europe = world[world['continent'] == 'Europe']

# %%
asia
# Out:
#         pop_est continent                  name iso_a3   gdp_md_est  \
# 5      18556698      Asia            Kazakhstan    KAZ    460700.00
# 6      29748859      Asia            Uzbekistan    UZB    202300.00
# 8     260580739      Asia             Indonesia    IDN   3028000.00
# 24      1291358      Asia           Timor-Leste    TLS      4975.00
# 76      8299706      Asia                Israel    ISR    297000.00
# 77      6229794      Asia               Lebanon    LBN     85160.00
# 79      4543126      Asia             Palestine    PSE     21220.77
# 83     10248069      Asia                Jordan    JOR     86190.00
# 84      6072475      Asia  United Arab Emirates    ARE    667200.00
# 85      2314307      Asia                 Qatar    QAT    334500.00
# 86      2875422      Asia                Kuwait    KWT    301100.00
# 87     39192111      Asia                  Iraq    IRQ    596700.00
# 88      3424386      Asia                  Oman    OMN    173100.00
# 90     16204486      Asia              Cambodia    KHM     58940.00
# 91     68414135      Asia              Thailand    THA   1161000.00
# 92      7126706      Asia                  Laos    LAO     40960.00
# 93     55123814      Asia               Myanmar    MMR    311100.00
# 94     96160163      Asia               Vietnam    VNM    594900.00
# 95     25248140      Asia           North Korea    PRK     40000.00
# 96     51181299      Asia           South Korea    KOR   1929000.00
# 97      3068243      Asia              Mongolia    MNG     37000.00
# 98   1281935911      Asia                 India    IND   8721000.00
# 99    157826578      Asia            Bangladesh    BGD    628400.00
# 15261          3       0  POINT (78.00000 21.00000)
# 15723          3       0  POINT (78.00000 21.00000)
# 16185          3       0  POINT (78.00000 21.00000)
# 16647          3       0  POINT (78.00000 21.00000)
# 17109          3       0  POINT (78.00000 21.00000)
# 17571          3       0  POINT (78.00000 21.00000)
# 18033          3       0  POINT (78.00000 21.00000)
# 18495          3       0  POINT (78.00000 21.00000)
# 18957          3       0  POINT (78.00000 21.00000)
# 19419          3       0  POINT (78.00000 21.00000)
# 19881          3       0  POINT (78.00000 21.00000)
# 20343          3       0  POINT (78.00000 21.00000)
# 20805          3       0  POINT (78.00000 21.00000)
# 21267          3       0  POINT (78.00000 21.00000)
# 21729          3       0  POINT (78.00000 21.00000)
# 22191          4       0  POINT (78.00000 21.00000)
# 22653          4       1  POINT (78.00000 21.00000)
# 23115          4       1  POINT (78.00000 21.00000)
# 23577          4       2  POINT (78.00000 21.00000)
# 24039          4       2  POINT (78.00000 21.00000)
# 24501         13       2  POINT (78.00000 21.00000)
# 24963         13       2  POINT (78.00000 21.00000)
# 25425         14       3  POINT (78.00000 21.00000)
# 25887         14       3  POINT (78.00000 21.00000)

# %%
fig,ax = plt.subplots(figsize=(20,10))
gdf01[gdf01['Country_Region'] == 'China'].plot(cmap='Purples',ax=ax)
world.geometry.boundary.plot(color=None,edgecolor='k',linewidth=2,ax=ax)

# %%
fig,ax = plt.subplots(figsize=(20,10))
gdf01[gdf01['Country_Region'] == 'China'].plot(cmap='Purples',ax=ax)
asia.geometry.boundary.plot(color=None,edgecolor='k',linewidth=2,ax=ax)

# %%
#time series trend
df2=df

# %%
import datetime as dt

# %%
df['cases_date'] = pd.to_datetime(df2['Date'])

# %%
df2.dtypes
# Out:
# Province_State            object
# Country_Region            object
# Lat                      float64
# Long                     float64
# Date                      object
# Confirmed                  int64
# Recovered                  int64
# Deaths                     int64
# geometry                geometry
# cases_date        datetime64[ns]
# dtype: object

# %%
df['cases_date'].plot(figsize=(20,10))

# %%
ts = df2.set_index('cases_date')

# %%
ts
# Out:
#            Province_State  Country_Region      Lat      Long     Date  \
# cases_date
# 2020-01-22            NaN        Thailand  15.0000  101.0000  1/22/20
# 2020-01-22            NaN           Japan  36.0000  138.0000  1/22/20
# 2020-01-22            NaN       Singapore   1.2833  103.8333  1/22/20
# 2020-01-22            NaN           Nepal  28.1667   84.2500  1/22/20
# 2020-01-22            NaN        Malaysia   2.5000  112.5000  1/22/20
# ...                   ...             ...      ...       ...      ...
# 2020-03-18          Aruba     Netherlands  12.5186  -70.0358  3/18/20
# 2020-03-18            NaN          Zambia -15.4167   28.2833  3/18/20
# 2020-03-18            NaN        Djibouti  11.8251   42.5903  3/18/20
# 2020-03-18            NaN     Gambia, The  13.4432  -15.3101  3/18/20
# 2020-03-18     Montserrat  United Kingdom  16.7425  -62.1874  3/18/20
#
#             Confirmed  Recovered  Deaths                    geometry
# cases_date
# 2020-01-22          2          0       0  POINT (101.00000 15.00000)
# 2020-01-22          2          0       0  POINT (138.00000 36.00000)
# 2020-01-22          0          0       0   POINT (103.83330 1.28330)
# 2020-01-22          0          0       0   POINT (84.25000 28.16670)
# 2020-01-22          0          0       0   POINT (112.50000 2.50000)
# ...               ...        ...     ...                         ...
# 2020-03-18          4          0       0  POINT (-70.03580 12.51860)
# 2020-03-18          2          0       0  POINT (28.28330 -15.41670)
# 2020-03-18          1          0       0   POINT (42.59030 11.82510)
# 2020-03-18          1          0       0  POINT (-15.31010 13.44320)
# 2020-03-18          1          0       0  POINT (-62.18740 16.74250)
#
# [26334 rows x 9 columns]

# %%
#Select for March
ts.loc['2020-03']
# Out:
#            Province_State  Country_Region      Lat      Long     Date  \
# cases_date
# 2020-03-01            NaN        Thailand  15.0000  101.0000   3/1/20
# 2020-03-01            NaN           Japan  36.0000  138.0000   3/1/20
# 2020-03-01            NaN       Singapore   1.2833  103.8333   3/1/20
# 2020-03-01            NaN           Nepal  28.1667   84.2500   3/1/20
# 2020-03-01            NaN        Malaysia   2.5000  112.5000   3/1/20
# ...                   ...             ...      ...       ...      ...
# 2020-03-18          Aruba     Netherlands  12.5186  -70.0358  3/18/20
# 2020-03-18            NaN          Zambia -15.4167   28.2833  3/18/20
# 2020-03-18            NaN        Djibouti  11.8251   42.5903  3/18/20
# 2020-03-18            NaN     Gambia, The  13.4432  -15.3101  3/18/20
# 2020-03-18     Montserrat  United Kingdom  16.7425  -62.1874  3/18/20
#
#             Confirmed  Recovered  Deaths                    geometry
# cases_date
# 2020-03-01         42         28       1  POINT (101.00000 15.00000)
# 2020-03-01        256         32       6  POINT (138.00000 36.00000)
# 2020-03-01        106         72       0   POINT (103.83330 1.28330)
# 2020-03-01          1          1       0   POINT (84.25000 28.16670)
# 2020-03-01         29         18       0   POINT (112.50000 2.50000)
# ...               ...        ...     ...                         ...
# 2020-03-18          4          0       0  POINT (-70.03580 12.51860)
# 2020-03-18          2          0       0  POINT (28.28330 -15.41670)
# 2020-03-18          1          0       0   POINT (42.59030 11.82510)
# 2020-03-18          1          0       0  POINT (-15.31010 13.44320)
# 2020-03-18          1          0       0  POINT (-62.18740 16.74250)
#
# [8316 rows x 9 columns]

# %%
ts.loc['2020-03-01':'2020-03-18'][['Confirmed','Deaths']].plot(figsize=(20,10))

# %%
df_by_date = ts.groupby(['cases_date']).sum().reset_index(drop=None)

# %%
df_by_date
# Out:
#    cases_date        Lat        Long  Confirmed  Recovered  Deaths
# 0  2020-01-22  14664.869 -16696.0541        555         28      17
# 1  2020-01-23  14664.869 -16696.0541        653         30      18
# 2  2020-01-24  14664.869 -16696.0541        941         36      26
# 3  2020-01-25  14664.869 -16696.0541       1434         39      42
# 4  2020-01-26  14664.869 -16696.0541       2118         52      56
# 5  2020-01-27  14664.869 -16696.0541       2927         61      82
# 6  2020-01-28  14664.869 -16696.0541       5578        107     131
# 7  2020-01-29  14664.869 -16696.0541       6166        126     133
# 8  2020-01-30  14664.869 -16696.0541       8234        143     171
# 9  2020-01-31  14664.869 -16696.0541       9927        222     213
# 10 2020-02-01  14664.869 -16696.0541      12038        284     259
# 11 2020-02-02  14664.869 -16696.0541      16787        472     362
